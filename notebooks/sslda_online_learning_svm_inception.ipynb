# %%
import os
import random
import glob
import random
import scipy.ndimage
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from imutils import paths
from sklearn import linear_model
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from keras.applications.inception_v3 import InceptionV3
from keras.applications import imagenet_utils
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
# Out:
# Using TensorFlow backend.

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
ROOT_DIR = os.path.normpath(os.path.join(os.path.dirname(os.path.realpath('__file__'))))
SOURCE_DIR = os.path.abspath('/data/aumkar/train')
TARGET_DIR = os.path.abspath('/data/aumkar/validation')
DATA_LOAD_DIR = os.path.abspath('/data/aumkar/data_load')

# %%
source_path = list(paths.list_images(SOURCE_DIR))
target_path = list(paths.list_images(TARGET_DIR))

# %%
random.shuffle(source_path)

# %%
random.shuffle(target_path)

# %%
(len(source_path), len(target_path))
# Out:
# (152397, 55388)

# %%
labels_source = [p.split(os.path.sep)[-2] for p in source_path]
labels_target = [p.split(os.path.sep)[-2] for p in target_path]

# %%
le = LabelEncoder()
labels = le.fit_transform(labels_source)
labels_t = le.fit_transform(labels_target)

# %%
labels_t.shape
# Out:
# (55388,)

# %%
labels_unique = np.load(os.path.join(DATA_LOAD_DIR, 'labels.npy'))

# %%
weights = {0 : 0.51, 1 : 1., 2 : 0.44, 3 : 0.57, 4 : 0.77, 5 : 0.51, 6 : 0.42, 7 : 0.6, 8 : 0.68, 9 : 0.63, 10 : 0.46, 11 : 0.76}

# %%
clf = linear_model.SGDClassifier(max_iter = 1000, tol = 1e-3, n_jobs = -1, class_weight = weights)

# %%
def model_create(transfer_model):
    if transfer_model == 'InceptionV3':
        with tf.device('/gpu:1'):
            return InceptionV3(weights = 'imagenet', include_top = False)
    elif transfer_model == 'VGG16':
        with tf.device('/gpu:1'):
            return VGG16(weights = 'imagenet', include_top = False)
    elif transfer_model == 'VGG19':
        with tf.device('/gpu:1'):
            return VGG19(weights = 'imagenet', include_top = False)
    elif transfer_model == 'Xception':
        with tf.device('/gpu:1'):
            return Xception(weights = 'imagenet', include_top = False)
    elif transfer_model == 'DenseNet121':
        with tf.device('/gpu:1'):
            return DenseNet121(weights = 'imagenet', include_top = False)

# %%
def model_reshape(transfer_model, features):
    if transfer_model == 'InceptionV3':
        return features.reshape((features.shape[0], 5 * 5 * 2048))
    elif transfer_model == 'VGG16':
        return features.reshape((features.shape[0], 7 * 7 * 512))
    elif transfer_model == 'VGG19':
        return features.reshape((features.shape[0], 7 * 7 * 512))
    elif transfer_model == 'Xception':
        return features.reshape((features.shape[0], 7 * 7 * 2048))
    elif transfer_model == 'DenseNet121':
        return features.reshape((features.shape[0], 7 * 7 * 1024))

# %%
def model_train(i, model, features, label):
    
    print('Training batch: ', i + 1)
    model.partial_fit(features, label, classes = labels_unique)
       
    return model

# %%
def feature_extract(tpath, spath, batch_size, pseudo_labels, source_labels, model_, source, trained_model, iteration, n_k):
    
    pred = []
    s_path = []
    model1 = model_create(model_)
    
    if source == 'target' and iteration != 0:
        
        idx = np.arange(len(tpath))
        np.random.shuffle(idx)
        
        sampled_idxs = idx[:int(n_k)]
        
        target_sample = np.array(tpath)[sampled_idxs]
        labels_sample = pseudo_labels[sampled_idxs]
        
        slabels = source_labels.tolist()
        
        spath = spath + target_sample.tolist()
        slabels = slabels + labels_sample.tolist()
        
        assert(len(spath) == len(slabels))
        
    for (b, i) in enumerate(range(0, len(spath), batch_size)):
        
        print("Processing batch {}/{}".format(b + 1, int(np.ceil(len(spath) / float(batch_size)))))
        
        batchPaths = spath[i: i + batch_size]
        if source == 'target' and iteration != 0:
            batchLabels = np.array(slabels)[i: i + batch_size]
        else:
            batchLabels = source_labels[i: i + batch_size]
        batchImages = []
        
        for imagePath in batchPaths:
            
            image = load_img(imagePath, target_size=(224, 224))
            image = img_to_array(image)

            image = np.expand_dims(image, axis=0)
            image = imagenet_utils.preprocess_input(image)

            batchImages.append(image)

        batchImages = np.vstack(batchImages)
            
        features = model1.predict(batchImages, batch_size = batch_size)
        features1 = model_reshape(model_, features)
        
        if source == 'source' and b == 0 and iteration == 0:
            model_partial = model_train(b, clf, features1, batchLabels)
        elif source == 'source' and b != 0 and iteration == 0:
            model_partial = model_train(b, model_partial, features1, batchLabels)
        elif source == 'target' and iteration == 0:
            pred.append(target_pred(trained_model, features1))
        elif source == 'target' and b == 0 and iteration != 0:
            model_partial = model_train(b, clf, features1, batchLabels)
        elif source == 'target' and b != 0 and iteration != 0:
            model_partial = model_train(b, model_partial, features1, batchLabels)

    if source == 'target' and iteration != 0:
        return model_partial
    if source == 'source' and iteration == 0:
        return model_partial
    elif source == 'target' and iteration == 0:
        return np.hstack(np.asarray(pred))

# %%
def target_pred(model, target_features):
    
    print('Predicting batch features')
    return model.predict(target_features)

# %%
def sslda_online(M):
    
    score = []
    
    svm_model = feature_extract(None, source_path, 256, None, labels, 'InceptionV3', 'source', None, 0, None)
    
    target_predictions = feature_extract(None, target_path, 256, None, labels_t, 'InceptionV3', 'target', svm_model, 0, None)
    
    for i in range(1, M):
        
        print('Iteration: ', i)
         
        n = (i / float(M)) * len(target_path)
        
        if i == 1:
            mod = feature_extract(target_path, source_path, 256, target_predictions, labels, 'InceptionV3', 'target', None, i, n)
            fin_pred = feature_extract(None, target_path, 256, None, labels_t, 'InceptionV3', 'target', mod, 0, None)
        else:
            mod = feature_extract(target_path, source_path, 256, fin_pred, labels, 'InceptionV3', 'target', None, i, n)
            fin_pred = feature_extract(None, target_path, 256, None, labels_t, 'InceptionV3', 'target', mod, 0, None)
        
        score.append(accuracy_score(labels_t, fin_pred))
        
    return fin_pred, score

# %%
pred = []
mean_acc = []

for i in range(3):
    
    print('ENSEMBLE ITERATION: ', i+1)
    
    sslda_pred, acc = sslda_online(10)
    
    pred.append(sslda_pred)
    mean_acc.append(acc)
# Out:
# ('ENSEMBLE ITERATION: ', 1)
# Processing batch 1/596
# ('Training batch: ', 1)
# Processing batch 2/596
# ('Training batch: ', 2)
# Processing batch 3/596
# ('Training batch: ', 3)
# Processing batch 4/596
# ('Training batch: ', 4)
# Processing batch 5/596
# ('Training batch: ', 5)
# Processing batch 6/596
# ('Training batch: ', 6)
# Processing batch 7/596
# ('Training batch: ', 7)
# Processing batch 8/596
# ('Training batch: ', 8)
# Processing batch 9/596
# ('Training batch: ', 9)
# Processing batch 10/596
# ('Training batch: ', 10)
# Processing batch 11/596
# ('Training batch: ', 11)
# Processing batch 12/596
# ('Training batch: ', 12)
# Processing batch 13/596
# ('Training batch: ', 13)
# Processing batch 14/596
# ('Training batch: ', 14)
# Processing batch 15/596
# ('Training batch: ', 15)
# Processing batch 16/596
# ('Training batch: ', 16)
# Processing batch 17/596
# ('Training batch: ', 17)
# Processing batch 18/596
# ('Training batch: ', 18)
# Processing batch 19/596
# ('Training batch: ', 19)
# Processing batch 20/596
# ('Training batch: ', 20)
# Processing batch 21/596
# ('Training batch: ', 21)
# Processing batch 22/596
# ('Training batch: ', 22)
# Processing batch 23/596
# ('Training batch: ', 23)
# Processing batch 24/596
# ('Training batch: ', 24)
# Processing batch 25/596
# ('Training batch: ', 25)
# Processing batch 26/596
# ('Training batch: ', 26)
# Processing batch 27/596
# ('Training batch: ', 27)
# Processing batch 28/596
# ('Training batch: ', 28)
# Processing batch 29/596
# ('Training batch: ', 29)
# Processing batch 30/596
# ('Training batch: ', 30)
# Processing batch 31/596
# ('Training batch: ', 31)
# Processing batch 32/596
# ('Training batch: ', 32)
# Processing batch 33/596
# ('Training batch: ', 33)
# Processing batch 34/596
# ('Training batch: ', 34)
# Processing batch 35/596
# ('Training batch: ', 35)
# Processing batch 36/596
# ('Training batch: ', 36)
# Processing batch 37/596
# ('Training batch: ', 37)
# Processing batch 38/596
# ('Training batch: ', 38)
# Processing batch 39/596
# ('Training batch: ', 39)
# Processing batch 40/596
# ('Training batch: ', 40)
# Processing batch 41/596
# ('Training batch: ', 41)
# Processing batch 42/596
# ('Training batch: ', 42)
# Processing batch 43/596
# ('Training batch: ', 43)
# Processing batch 44/596
# ('Training batch: ', 44)
# Processing batch 45/596
# ('Training batch: ', 45)
# Processing batch 46/596
# ('Training batch: ', 46)
# Processing batch 47/596
# ('Training batch: ', 47)
# Processing batch 48/596
# ('Training batch: ', 48)
# Processing batch 49/596
# ('Training batch: ', 49)
# Processing batch 50/596
# ('Training batch: ', 50)
# Processing batch 51/596
# ('Training batch: ', 51)
# Processing batch 52/596
# ('Training batch: ', 52)
# Processing batch 53/596
# ('Training batch: ', 53)
# Processing batch 54/596
# ('Training batch: ', 54)
# Processing batch 55/596
# ('Training batch: ', 55)
# Processing batch 56/596
# ('Training batch: ', 56)
# Processing batch 57/596
# ('Training batch: ', 57)
# Processing batch 58/596
# ('Training batch: ', 58)
# Processing batch 59/596
# ('Training batch: ', 59)
# Processing batch 60/596
# ('Training batch: ', 60)
# Processing batch 61/596
# ('Training batch: ', 61)
# Processing batch 62/596
# ('Training batch: ', 62)
# Processing batch 63/596
# ('Training batch: ', 63)
# Processing batch 64/596
# ('Training batch: ', 64)
# Processing batch 65/596
# ('Training batch: ', 65)
# Processing batch 66/596
# ('Training batch: ', 66)
# Processing batch 67/596
# ('Training batch: ', 67)
# Processing batch 68/596
# ('Training batch: ', 68)
# Processing batch 69/596
# ('Training batch: ', 69)
# Processing batch 70/596
# ('Training batch: ', 70)
# Processing batch 71/596
# ('Training batch: ', 71)
# Processing batch 72/596
# ('Training batch: ', 72)
# Processing batch 73/596
# ('Training batch: ', 73)
# Processing batch 74/596
# ('Training batch: ', 74)
# Processing batch 75/596
# ('Training batch: ', 75)
# Processing batch 76/596
# ('Training batch: ', 76)
# Processing batch 77/596
# ('Training batch: ', 77)
# Processing batch 78/596
# ('Training batch: ', 78)
# Processing batch 79/596
# ('Training batch: ', 79)
# Processing batch 80/596
# ('Training batch: ', 80)
# Processing batch 81/596
# ('Training batch: ', 81)
# Processing batch 82/596
# ('Training batch: ', 82)
# Processing batch 83/596
# ('Training batch: ', 83)
# Processing batch 84/596
# ('Training batch: ', 84)
# Processing batch 85/596
# ('Training batch: ', 85)
# Processing batch 86/596
# ('Training batch: ', 86)
# Processing batch 87/596
# ('Training batch: ', 87)
# Processing batch 88/596
# ('Training batch: ', 88)
# Processing batch 89/596
# ('Training batch: ', 89)
# Processing batch 90/596
# ('Training batch: ', 90)
# Processing batch 91/596
# ('Training batch: ', 91)
# Processing batch 92/596
# ('Training batch: ', 92)
# Processing batch 93/596
# ('Training batch: ', 93)
# Processing batch 94/596
# ('Training batch: ', 94)
# Processing batch 95/596
# ('Training batch: ', 95)
# Processing batch 96/596
# ('Training batch: ', 96)
# Processing batch 97/596
# ('Training batch: ', 97)
# Processing batch 98/596
# ('Training batch: ', 98)
# Processing batch 99/596
# ('Training batch: ', 99)
# Processing batch 100/596
# ('Training batch: ', 100)
# Processing batch 101/596
# ('Training batch: ', 101)
# Processing batch 102/596
# ('Training batch: ', 102)
# Processing batch 103/596
# ('Training batch: ', 103)
# Processing batch 104/596
# ('Training batch: ', 104)
# Processing batch 105/596
# ('Training batch: ', 105)
# Processing batch 106/596
# ('Training batch: ', 106)
# Processing batch 107/596
# ('Training batch: ', 107)
# Processing batch 108/596
# ('Training batch: ', 108)
# Processing batch 109/596
# ('Training batch: ', 109)
# Processing batch 110/596
# ('Training batch: ', 110)
# Processing batch 111/596
# ('Training batch: ', 111)
# Processing batch 112/596
# ('Training batch: ', 112)
# Processing batch 113/596
# ('Training batch: ', 113)
# Processing batch 114/596
# ('Training batch: ', 114)
# Processing batch 115/596
# ('Training batch: ', 115)
# Processing batch 116/596
# ('Training batch: ', 116)
# Processing batch 117/596
# ('Training batch: ', 117)
# Processing batch 118/596
# ('Training batch: ', 118)
# Processing batch 119/596
# ('Training batch: ', 119)
# Processing batch 120/596
# ('Training batch: ', 120)
# Processing batch 121/596
# ('Training batch: ', 121)
# Processing batch 122/596
# ('Training batch: ', 122)
# Processing batch 123/596
# ('Training batch: ', 123)
# Processing batch 124/596
# ('Training batch: ', 124)
# Processing batch 125/596
# ('Training batch: ', 125)
# Processing batch 126/596
# ('Training batch: ', 126)
# Processing batch 127/596
# ('Training batch: ', 127)
# Processing batch 128/596
# ('Training batch: ', 128)
# Processing batch 129/596
# ('Training batch: ', 129)
# Processing batch 130/596
# ('Training batch: ', 130)
# Processing batch 131/596
# ('Training batch: ', 131)
# Processing batch 132/596
# ('Training batch: ', 132)
# Processing batch 133/596
# ('Training batch: ', 133)
# Processing batch 134/596
# ('Training batch: ', 134)
# Processing batch 135/596
# ('Training batch: ', 135)
# Processing batch 136/596
# ('Training batch: ', 136)
# Processing batch 137/596
# ('Training batch: ', 137)
# Processing batch 138/596
# ('Training batch: ', 138)
# Processing batch 139/596
# ('Training batch: ', 139)
# Processing batch 140/596
# ('Training batch: ', 140)
# Processing batch 141/596
# ('Training batch: ', 141)
# Processing batch 142/596
# ('Training batch: ', 142)
# Processing batch 143/596
# ('Training batch: ', 143)
# Processing batch 144/596
# ('Training batch: ', 144)
# Processing batch 145/596
# ('Training batch: ', 145)
# Processing batch 146/596
# ('Training batch: ', 146)
# Processing batch 147/596
# ('Training batch: ', 147)
# Processing batch 148/596
# ('Training batch: ', 148)
# Processing batch 149/596
# ('Training batch: ', 149)
# Processing batch 150/596
# ('Training batch: ', 150)
# Processing batch 151/596
# ('Training batch: ', 151)
# Processing batch 152/596
# ('Training batch: ', 152)
# Processing batch 153/596
# ('Training batch: ', 153)
# Processing batch 154/596
# ('Training batch: ', 154)
# Processing batch 155/596
# ('Training batch: ', 155)
# Processing batch 156/596
# ('Training batch: ', 156)
# Processing batch 157/596
# ('Training batch: ', 157)
# Processing batch 158/596
# ('Training batch: ', 158)
# Processing batch 159/596
# ('Training batch: ', 159)
# Processing batch 160/596
# ('Training batch: ', 160)
# Processing batch 161/596
# ('Training batch: ', 161)
# Processing batch 162/596
# ('Training batch: ', 162)
# Processing batch 163/596
# ('Training batch: ', 163)
# Processing batch 164/596
# ('Training batch: ', 164)
# Processing batch 165/596
# ('Training batch: ', 165)
# Processing batch 166/596
# ('Training batch: ', 166)
# Processing batch 167/596
# ('Training batch: ', 167)
# Processing batch 168/596
# ('Training batch: ', 168)
# Processing batch 169/596
# ('Training batch: ', 169)
# Processing batch 170/596
# ('Training batch: ', 170)
# Processing batch 171/596
# ('Training batch: ', 171)
# Processing batch 172/596
# ('Training batch: ', 172)
# Processing batch 173/596
# ('Training batch: ', 173)
# Processing batch 174/596
# ('Training batch: ', 174)
# Processing batch 175/596
# ('Training batch: ', 175)
# Processing batch 176/596
# ('Training batch: ', 176)
# Processing batch 177/596
# ('Training batch: ', 177)
# Processing batch 178/596
# ('Training batch: ', 178)
# Processing batch 179/596
# ('Training batch: ', 179)
# Processing batch 180/596
# ('Training batch: ', 180)
# Processing batch 181/596
# ('Training batch: ', 181)
# Processing batch 182/596
# ('Training batch: ', 182)
# Processing batch 183/596
# ('Training batch: ', 183)
# Processing batch 184/596
# ('Training batch: ', 184)
# Processing batch 185/596
# ('Training batch: ', 185)
# Processing batch 186/596
# ('Training batch: ', 186)
# Processing batch 187/596
# ('Training batch: ', 187)
# Processing batch 188/596
# ('Training batch: ', 188)
# Processing batch 189/596
# ('Training batch: ', 189)
# Processing batch 190/596
# ('Training batch: ', 190)
# Processing batch 191/596
# ('Training batch: ', 191)
# Processing batch 192/596
# ('Training batch: ', 192)
# Processing batch 193/596
# ('Training batch: ', 193)
# Processing batch 194/596
# ('Training batch: ', 194)
# Processing batch 195/596
# ('Training batch: ', 195)
# Processing batch 196/596
# ('Training batch: ', 196)
# Processing batch 197/596
# ('Training batch: ', 197)
# Processing batch 198/596
# ('Training batch: ', 198)
# Processing batch 199/596
# ('Training batch: ', 199)
# Processing batch 200/596
# ('Training batch: ', 200)
# Processing batch 201/596
# ('Training batch: ', 201)
# Processing batch 202/596
# ('Training batch: ', 202)
# Processing batch 203/596
# ('Training batch: ', 203)
# Processing batch 204/596
# ('Training batch: ', 204)
# Processing batch 205/596
# ('Training batch: ', 205)
# Processing batch 206/596
# ('Training batch: ', 206)
# Processing batch 207/596
# ('Training batch: ', 207)
# Processing batch 208/596
# ('Training batch: ', 208)
# Processing batch 209/596
# ('Training batch: ', 209)
# Processing batch 210/596
# ('Training batch: ', 210)
# Processing batch 211/596
# ('Training batch: ', 211)
# Processing batch 212/596
# ('Training batch: ', 212)
# Processing batch 213/596
# ('Training batch: ', 213)
# Processing batch 214/596
# ('Training batch: ', 214)
# Processing batch 215/596
# ('Training batch: ', 215)
# Processing batch 216/596
# ('Training batch: ', 216)
# Processing batch 217/596
# ('Training batch: ', 217)
# Processing batch 218/596
# ('Training batch: ', 218)
# Processing batch 219/596
# ('Training batch: ', 219)
# Processing batch 220/596
# ('Training batch: ', 220)
# Processing batch 221/596
# ('Training batch: ', 221)
# Processing batch 222/596
# ('Training batch: ', 222)
# Processing batch 223/596
# ('Training batch: ', 223)
# Processing batch 224/596
# ('Training batch: ', 224)
# Processing batch 225/596
# ('Training batch: ', 225)
# Processing batch 226/596
# ('Training batch: ', 226)
# Processing batch 227/596
# ('Training batch: ', 227)
# Processing batch 228/596
# ('Training batch: ', 228)
# Processing batch 229/596
# ('Training batch: ', 229)
# Processing batch 230/596
# ('Training batch: ', 230)
# Processing batch 231/596
# ('Training batch: ', 231)
# Processing batch 232/596
# ('Training batch: ', 232)
# Processing batch 233/596
# ('Training batch: ', 233)
# Processing batch 234/596
# ('Training batch: ', 234)
# Processing batch 235/596
# ('Training batch: ', 235)
# Processing batch 236/596
# ('Training batch: ', 236)
# Processing batch 237/596
# ('Training batch: ', 237)
# Processing batch 238/596
# ('Training batch: ', 238)
# Processing batch 239/596
# ('Training batch: ', 239)
# Processing batch 240/596
# ('Training batch: ', 240)
# Processing batch 241/596
# ('Training batch: ', 241)
# Processing batch 242/596
# ('Training batch: ', 242)
# Processing batch 243/596
# ('Training batch: ', 243)
# Processing batch 244/596
# ('Training batch: ', 244)
# Processing batch 245/596
# ('Training batch: ', 245)
# Processing batch 246/596
# ('Training batch: ', 246)
# Processing batch 247/596
# ('Training batch: ', 247)
# Processing batch 248/596
# ('Training batch: ', 248)
# Processing batch 249/596
# ('Training batch: ', 249)
# Processing batch 250/596
# ('Training batch: ', 250)
# Processing batch 251/596
# ('Training batch: ', 251)
# Processing batch 252/596
# ('Training batch: ', 252)
# Processing batch 253/596
# ('Training batch: ', 253)
# Processing batch 254/596
# ('Training batch: ', 254)
# Processing batch 255/596
# ('Training batch: ', 255)
# Processing batch 256/596
# ('Training batch: ', 256)
# Processing batch 257/596
# ('Training batch: ', 257)
# Processing batch 258/596
# ('Training batch: ', 258)
# Processing batch 259/596
# ('Training batch: ', 259)
# Processing batch 260/596
# ('Training batch: ', 260)
# Processing batch 261/596
# ('Training batch: ', 261)
# Processing batch 262/596
# ('Training batch: ', 262)
# Processing batch 263/596
# ('Training batch: ', 263)
# Processing batch 264/596
# ('Training batch: ', 264)
# Processing batch 265/596
# ('Training batch: ', 265)
# Processing batch 266/596
# ('Training batch: ', 266)
# Processing batch 267/596
# ('Training batch: ', 267)
# Processing batch 268/596
# ('Training batch: ', 268)
# Processing batch 269/596
# ('Training batch: ', 269)
# Processing batch 270/596
# ('Training batch: ', 270)
# Processing batch 271/596
# ('Training batch: ', 271)
# Processing batch 272/596
# ('Training batch: ', 272)
# Processing batch 273/596
# ('Training batch: ', 273)
# Processing batch 274/596
# ('Training batch: ', 274)
# Processing batch 275/596
# ('Training batch: ', 275)
# Processing batch 276/596
# ('Training batch: ', 276)
# Processing batch 277/596
# ('Training batch: ', 277)
# Processing batch 278/596
# ('Training batch: ', 278)
# Processing batch 279/596
# ('Training batch: ', 279)
# Processing batch 280/596
# ('Training batch: ', 280)
# Processing batch 281/596
# ('Training batch: ', 281)
# Processing batch 282/596
# ('Training batch: ', 282)
# Processing batch 283/596
# ('Training batch: ', 283)
# Processing batch 284/596
# ('Training batch: ', 284)
# Processing batch 285/596
# ('Training batch: ', 285)
# Processing batch 286/596
# ('Training batch: ', 286)
# Processing batch 287/596
# ('Training batch: ', 287)
# Processing batch 288/596
# ('Training batch: ', 288)
# Processing batch 289/596
# ('Training batch: ', 289)
# Processing batch 290/596
# ('Training batch: ', 290)
# Processing batch 291/596
# ('Training batch: ', 291)
# Processing batch 292/596
# ('Training batch: ', 292)
# Processing batch 293/596
# ('Training batch: ', 293)
# Processing batch 294/596
# ('Training batch: ', 294)
# Processing batch 295/596
# ('Training batch: ', 295)
# Processing batch 296/596
# ('Training batch: ', 296)
# Processing batch 297/596
# ('Training batch: ', 297)
# Processing batch 298/596
# ('Training batch: ', 298)
# Processing batch 299/596
# ('Training batch: ', 299)
# Processing batch 300/596
# ('Training batch: ', 300)
# Processing batch 301/596
# ('Training batch: ', 301)
# Processing batch 302/596
# ('Training batch: ', 302)
# Processing batch 303/596
# ('Training batch: ', 303)
# Processing batch 304/596
# ('Training batch: ', 304)
# Processing batch 305/596
# ('Training batch: ', 305)
# Processing batch 306/596
# ('Training batch: ', 306)
# Processing batch 307/596
# ('Training batch: ', 307)
# Processing batch 308/596
# ('Training batch: ', 308)
# Processing batch 309/596
# ('Training batch: ', 309)
# Processing batch 310/596
# ('Training batch: ', 310)
# Processing batch 311/596
# ('Training batch: ', 311)
# Processing batch 312/596
# ('Training batch: ', 312)
# Processing batch 313/596
# ('Training batch: ', 313)
# Processing batch 314/596
# ('Training batch: ', 314)
# Processing batch 315/596
# ('Training batch: ', 315)
# Processing batch 316/596
# ('Training batch: ', 316)
# Processing batch 317/596
# ('Training batch: ', 317)
# Processing batch 318/596
# ('Training batch: ', 318)
# Processing batch 319/596
# ('Training batch: ', 319)
# Processing batch 320/596
# ('Training batch: ', 320)
# Processing batch 321/596
# ('Training batch: ', 321)
# Processing batch 322/596
# ('Training batch: ', 322)
# Processing batch 323/596
# ('Training batch: ', 323)
# Processing batch 324/596
# ('Training batch: ', 324)
# Processing batch 325/596
# ('Training batch: ', 325)
# Processing batch 326/596
# ('Training batch: ', 326)
# Processing batch 327/596
# ('Training batch: ', 327)
# Processing batch 328/596
# ('Training batch: ', 328)
# Processing batch 329/596
# ('Training batch: ', 329)
# Processing batch 330/596
# ('Training batch: ', 330)
# Processing batch 331/596
# ('Training batch: ', 331)
# Processing batch 332/596
# ('Training batch: ', 332)
# Processing batch 333/596
# ('Training batch: ', 333)
# Processing batch 334/596
# ('Training batch: ', 334)
# Processing batch 335/596
# ('Training batch: ', 335)
# Processing batch 336/596
# ('Training batch: ', 336)
# Processing batch 337/596
# ('Training batch: ', 337)
# Processing batch 338/596
# ('Training batch: ', 338)
# Processing batch 339/596
# ('Training batch: ', 339)
# Processing batch 340/596
# ('Training batch: ', 340)
# Processing batch 341/596
# ('Training batch: ', 341)
# Processing batch 342/596
# ('Training batch: ', 342)
# Processing batch 343/596
# ('Training batch: ', 343)
# Processing batch 344/596
# ('Training batch: ', 344)
# Processing batch 345/596
# ('Training batch: ', 345)
# Processing batch 346/596
# ('Training batch: ', 346)
# Processing batch 347/596
# ('Training batch: ', 347)
# Processing batch 348/596
# ('Training batch: ', 348)
# Processing batch 349/596
# ('Training batch: ', 349)
# Processing batch 350/596
# ('Training batch: ', 350)
# Processing batch 351/596
# ('Training batch: ', 351)
# Processing batch 352/596
# ('Training batch: ', 352)
# Processing batch 353/596
# ('Training batch: ', 353)
# Processing batch 354/596
# ('Training batch: ', 354)
# Processing batch 355/596
# ('Training batch: ', 355)
# Processing batch 356/596
# ('Training batch: ', 356)
# Processing batch 357/596
# ('Training batch: ', 357)
# Processing batch 358/596
# ('Training batch: ', 358)
# Processing batch 359/596
# ('Training batch: ', 359)
# Processing batch 360/596
# ('Training batch: ', 360)
# Processing batch 361/596
# ('Training batch: ', 361)
# Processing batch 362/596
# ('Training batch: ', 362)
# Processing batch 363/596
# ('Training batch: ', 363)
# Processing batch 364/596
# ('Training batch: ', 364)
# Processing batch 365/596
# ('Training batch: ', 365)
# Processing batch 366/596
# ('Training batch: ', 366)
# Processing batch 367/596
# ('Training batch: ', 367)
# Processing batch 368/596
# ('Training batch: ', 368)
# Processing batch 369/596
# ('Training batch: ', 369)
# Processing batch 370/596
# ('Training batch: ', 370)
# Processing batch 371/596
# ('Training batch: ', 371)
# Processing batch 372/596
# ('Training batch: ', 372)
# Processing batch 373/596
# ('Training batch: ', 373)
# Processing batch 374/596
# ('Training batch: ', 374)
# Processing batch 375/596
# ('Training batch: ', 375)
# Processing batch 376/596
# ('Training batch: ', 376)
# Processing batch 377/596
# ('Training batch: ', 377)
# Processing batch 378/596
# ('Training batch: ', 378)
# Processing batch 379/596
# ('Training batch: ', 379)
# Processing batch 380/596
# ('Training batch: ', 380)
# Processing batch 381/596
# ('Training batch: ', 381)
# Processing batch 382/596
# ('Training batch: ', 382)
# Processing batch 383/596
# ('Training batch: ', 383)
# Processing batch 384/596
# ('Training batch: ', 384)
# Processing batch 385/596
# ('Training batch: ', 385)
# Processing batch 386/596
# ('Training batch: ', 386)
# Processing batch 387/596
# ('Training batch: ', 387)
# Processing batch 388/596
# ('Training batch: ', 388)
# Processing batch 389/596
# ('Training batch: ', 389)
# Processing batch 390/596
# ('Training batch: ', 390)
# Processing batch 391/596
# ('Training batch: ', 391)
# Processing batch 392/596
# ('Training batch: ', 392)
# Processing batch 393/596
# ('Training batch: ', 393)
# Processing batch 394/596
# ('Training batch: ', 394)
# Processing batch 395/596
# ('Training batch: ', 395)
# Processing batch 396/596
# ('Training batch: ', 396)
# Processing batch 397/596
# ('Training batch: ', 397)
# Processing batch 398/596
# ('Training batch: ', 398)
# Processing batch 399/596
# ('Training batch: ', 399)
# Processing batch 400/596
# ('Training batch: ', 400)
# Processing batch 401/596
# ('Training batch: ', 401)
# Processing batch 402/596
# ('Training batch: ', 402)
# Processing batch 403/596
# ('Training batch: ', 403)
# Processing batch 404/596
# ('Training batch: ', 404)
# Processing batch 405/596
# ('Training batch: ', 405)
# Processing batch 406/596
# ('Training batch: ', 406)
# Processing batch 407/596
# ('Training batch: ', 407)
# Processing batch 408/596
# ('Training batch: ', 408)
# Processing batch 409/596
# ('Training batch: ', 409)
# Processing batch 410/596
# ('Training batch: ', 410)
# Processing batch 411/596
# ('Training batch: ', 411)
# Processing batch 412/596
# ('Training batch: ', 412)
# Processing batch 413/596
# ('Training batch: ', 413)
# Processing batch 414/596
# ('Training batch: ', 414)
# Processing batch 415/596
# ('Training batch: ', 415)
# Processing batch 416/596
# ('Training batch: ', 416)
# Processing batch 417/596
# ('Training batch: ', 417)
# Processing batch 418/596
# ('Training batch: ', 418)
# Processing batch 419/596
# ('Training batch: ', 419)
# Processing batch 420/596
# ('Training batch: ', 420)
# Processing batch 421/596
# ('Training batch: ', 421)
# Processing batch 422/596
# ('Training batch: ', 422)
# Processing batch 423/596
# ('Training batch: ', 423)
# Processing batch 424/596
# ('Training batch: ', 424)
# Processing batch 425/596
# ('Training batch: ', 425)
# Processing batch 426/596
# ('Training batch: ', 426)
# Processing batch 427/596
# ('Training batch: ', 427)
# Processing batch 428/596
# ('Training batch: ', 428)
# Processing batch 429/596
# ('Training batch: ', 429)
# Processing batch 430/596
# ('Training batch: ', 430)
# Processing batch 431/596
# ('Training batch: ', 431)
# Processing batch 432/596
# ('Training batch: ', 432)
# Processing batch 433/596
# ('Training batch: ', 433)
# Processing batch 434/596
# ('Training batch: ', 434)
# Processing batch 435/596
# ('Training batch: ', 435)
# Processing batch 436/596
# ('Training batch: ', 436)
# Processing batch 437/596
# ('Training batch: ', 437)
# Processing batch 438/596
# ('Training batch: ', 438)
# Processing batch 439/596
# ('Training batch: ', 439)
# Processing batch 440/596
# ('Training batch: ', 440)
# Processing batch 441/596
# ('Training batch: ', 441)
# Processing batch 442/596
# ('Training batch: ', 442)
# Processing batch 443/596
# ('Training batch: ', 443)
# Processing batch 444/596
# ('Training batch: ', 444)
# Processing batch 445/596
# ('Training batch: ', 445)
# Processing batch 446/596
# ('Training batch: ', 446)
# Processing batch 447/596
# ('Training batch: ', 447)
# Processing batch 448/596
# ('Training batch: ', 448)
# Processing batch 449/596
# ('Training batch: ', 449)
# Processing batch 450/596
# ('Training batch: ', 450)
# Processing batch 451/596
# ('Training batch: ', 451)
# Processing batch 452/596
# ('Training batch: ', 452)
# Processing batch 453/596
# ('Training batch: ', 453)
# Processing batch 454/596
# ('Training batch: ', 454)
# Processing batch 455/596
# ('Training batch: ', 455)
# Processing batch 456/596
# ('Training batch: ', 456)
# Processing batch 457/596
# ('Training batch: ', 457)
# Processing batch 458/596
# ('Training batch: ', 458)
# Processing batch 459/596
# ('Training batch: ', 459)
# Processing batch 460/596
# ('Training batch: ', 460)
# Processing batch 461/596
# ('Training batch: ', 461)
# Processing batch 462/596
# ('Training batch: ', 462)
# Processing batch 463/596
# ('Training batch: ', 463)
# Processing batch 464/596
# ('Training batch: ', 464)
# Processing batch 465/596
# ('Training batch: ', 465)
# Processing batch 466/596
# ('Training batch: ', 466)
# Processing batch 467/596
# ('Training batch: ', 467)
# Processing batch 468/596
# ('Training batch: ', 468)
# Processing batch 469/596
# ('Training batch: ', 469)
# Processing batch 470/596
# ('Training batch: ', 470)
# Processing batch 471/596
# ('Training batch: ', 471)
# Processing batch 472/596
# ('Training batch: ', 472)
# Processing batch 473/596
# ('Training batch: ', 473)
# Processing batch 474/596
# ('Training batch: ', 474)
# Processing batch 475/596
# ('Training batch: ', 475)
# Processing batch 476/596
# ('Training batch: ', 476)
# Processing batch 477/596
# ('Training batch: ', 477)
# Processing batch 478/596
# ('Training batch: ', 478)
# Processing batch 479/596
# ('Training batch: ', 479)
# Processing batch 480/596
# ('Training batch: ', 480)
# Processing batch 481/596
# ('Training batch: ', 481)
# Processing batch 482/596
# ('Training batch: ', 482)
# Processing batch 483/596
# ('Training batch: ', 483)
# Processing batch 484/596
# ('Training batch: ', 484)
# Processing batch 485/596
# ('Training batch: ', 485)
# Processing batch 486/596
# ('Training batch: ', 486)
# Processing batch 487/596
# ('Training batch: ', 487)
# Processing batch 488/596
# ('Training batch: ', 488)
# Processing batch 489/596
# ('Training batch: ', 489)
# Processing batch 490/596
# ('Training batch: ', 490)
# Processing batch 491/596
# ('Training batch: ', 491)
# Processing batch 492/596
# ('Training batch: ', 492)
# Processing batch 493/596
# ('Training batch: ', 493)
# Processing batch 494/596
# ('Training batch: ', 494)
# Processing batch 495/596
# ('Training batch: ', 495)
# Processing batch 496/596
# ('Training batch: ', 496)
# Processing batch 497/596
# ('Training batch: ', 497)
# Processing batch 498/596
# ('Training batch: ', 498)
# Processing batch 499/596
# ('Training batch: ', 499)
# Processing batch 500/596
# ('Training batch: ', 500)
# Processing batch 501/596
# ('Training batch: ', 501)
# Processing batch 502/596
# ('Training batch: ', 502)
# Processing batch 503/596
# ('Training batch: ', 503)
# Processing batch 504/596
# ('Training batch: ', 504)
# Processing batch 505/596
# ('Training batch: ', 505)
# Processing batch 506/596
# ('Training batch: ', 506)
# Processing batch 507/596
# ('Training batch: ', 507)
# Processing batch 508/596
# ('Training batch: ', 508)
# Processing batch 509/596
# ('Training batch: ', 509)
# Processing batch 510/596
# ('Training batch: ', 510)
# Processing batch 511/596
# ('Training batch: ', 511)
# Processing batch 512/596
# ('Training batch: ', 512)
# Processing batch 513/596
# ('Training batch: ', 513)
# Processing batch 514/596
# ('Training batch: ', 514)
# Processing batch 515/596
# ('Training batch: ', 515)
# Processing batch 516/596
# ('Training batch: ', 516)
# Processing batch 517/596
# ('Training batch: ', 517)
# Processing batch 518/596
# ('Training batch: ', 518)
# Processing batch 519/596
# ('Training batch: ', 519)
# Processing batch 520/596
# ('Training batch: ', 520)
# Processing batch 521/596
# ('Training batch: ', 521)
# Processing batch 522/596
# ('Training batch: ', 522)
# Processing batch 523/596
# ('Training batch: ', 523)
# Processing batch 524/596
# ('Training batch: ', 524)
# Processing batch 525/596
# ('Training batch: ', 525)
# Processing batch 526/596
# ('Training batch: ', 526)
# Processing batch 527/596
# ('Training batch: ', 527)
# Processing batch 528/596
# ('Training batch: ', 528)
# Processing batch 529/596
# ('Training batch: ', 529)
# Processing batch 530/596
# ('Training batch: ', 530)
# Processing batch 531/596
# ('Training batch: ', 531)
# Processing batch 532/596
# ('Training batch: ', 532)
# Processing batch 533/596
# ('Training batch: ', 533)
# Processing batch 534/596
# ('Training batch: ', 534)
# Processing batch 535/596
# ('Training batch: ', 535)
# Processing batch 536/596
# ('Training batch: ', 536)
# Processing batch 537/596
# ('Training batch: ', 537)
# Processing batch 538/596
# ('Training batch: ', 538)
# Processing batch 539/596
# ('Training batch: ', 539)
# Processing batch 540/596
# ('Training batch: ', 540)
# Processing batch 541/596
# ('Training batch: ', 541)
# Processing batch 542/596
# ('Training batch: ', 542)
# Processing batch 543/596
# ('Training batch: ', 543)
# Processing batch 544/596
# ('Training batch: ', 544)
# Processing batch 545/596
# ('Training batch: ', 545)
# Processing batch 546/596
# ('Training batch: ', 546)
# Processing batch 547/596
# ('Training batch: ', 547)
# Processing batch 548/596
# ('Training batch: ', 548)
# Processing batch 549/596
# ('Training batch: ', 549)
# Processing batch 550/596
# ('Training batch: ', 550)
# Processing batch 551/596
# ('Training batch: ', 551)
# Processing batch 552/596
# ('Training batch: ', 552)
# Processing batch 553/596
# ('Training batch: ', 553)
# Processing batch 554/596
# ('Training batch: ', 554)
# Processing batch 555/596
# ('Training batch: ', 555)
# Processing batch 556/596
# ('Training batch: ', 556)
# Processing batch 557/596
# ('Training batch: ', 557)
# Processing batch 558/596
# ('Training batch: ', 558)
# Processing batch 559/596
# ('Training batch: ', 559)
# Processing batch 560/596
# ('Training batch: ', 560)
# Processing batch 561/596
# ('Training batch: ', 561)
# Processing batch 562/596
# ('Training batch: ', 562)
# Processing batch 563/596
# ('Training batch: ', 563)
# Processing batch 564/596
# ('Training batch: ', 564)
# Processing batch 565/596
# ('Training batch: ', 565)
# Processing batch 566/596
# ('Training batch: ', 566)
# Processing batch 567/596
# ('Training batch: ', 567)
# Processing batch 568/596
# ('Training batch: ', 568)
# Processing batch 569/596
# ('Training batch: ', 569)
# Processing batch 570/596
# ('Training batch: ', 570)
# Processing batch 571/596
# ('Training batch: ', 571)
# Processing batch 572/596
# ('Training batch: ', 572)
# Processing batch 573/596
# ('Training batch: ', 573)
# Processing batch 574/596
# ('Training batch: ', 574)
# Processing batch 575/596
# ('Training batch: ', 575)
# Processing batch 576/596
# ('Training batch: ', 576)
# Processing batch 577/596
# ('Training batch: ', 577)
# Processing batch 578/596
# ('Training batch: ', 578)
# Processing batch 579/596
# ('Training batch: ', 579)
# Processing batch 580/596
# ('Training batch: ', 580)
# Processing batch 581/596
# ('Training batch: ', 581)
# Processing batch 582/596
# ('Training batch: ', 582)
# Processing batch 583/596
# ('Training batch: ', 583)
# Processing batch 584/596
# ('Training batch: ', 584)
# Processing batch 585/596
# ('Training batch: ', 585)
# Processing batch 586/596
# ('Training batch: ', 586)
# Processing batch 587/596
# ('Training batch: ', 587)
# Processing batch 588/596
# ('Training batch: ', 588)
# Processing batch 589/596
# ('Training batch: ', 589)
# Processing batch 590/596
# ('Training batch: ', 590)
# Processing batch 591/596
# ('Training batch: ', 591)
# Processing batch 592/596
# ('Training batch: ', 592)
# Processing batch 593/596
# ('Training batch: ', 593)
# Processing batch 594/596
# ('Training batch: ', 594)
# Processing batch 595/596
# ('Training batch: ', 595)
# Processing batch 596/596
# ('Training batch: ', 596)
# Processing batch 1/217
# Predicting batch features
# Processing batch 2/217
# Predicting batch features
# Processing batch 3/217
# Predicting batch features
# Processing batch 4/217
# Predicting batch features
# Processing batch 5/217
# Predicting batch features
# Processing batch 6/217
# Predicting batch features
# Processing batch 7/217
# Predicting batch features
# Processing batch 8/217
# Predicting batch features
# Processing batch 9/217
# Predicting batch features
# Processing batch 10/217
# Predicting batch features
# Processing batch 11/217
# Predicting batch features
# Processing batch 12/217
# Predicting batch features
# Processing batch 13/217
# Predicting batch features
# Processing batch 14/217
# Predicting batch features
# Processing batch 15/217
# Predicting batch features
# Processing batch 16/217
# Predicting batch features
# Processing batch 17/217
# Predicting batch features
# Processing batch 18/217
# Predicting batch features
# Processing batch 19/217
# Predicting batch features
# Processing batch 20/217
# Predicting batch features
# Processing batch 21/217
# Predicting batch features
# Processing batch 22/217
# Predicting batch features
# Processing batch 23/217
# Predicting batch features
# Processing batch 24/217
# Predicting batch features
# Processing batch 25/217
# Predicting batch features
# Processing batch 26/217
# Predicting batch features
# Processing batch 27/217
# Predicting batch features
# Processing batch 28/217
# Predicting batch features
# Processing batch 29/217
# Predicting batch features
# Processing batch 30/217
# Predicting batch features
# Processing batch 31/217
# Predicting batch features
# Processing batch 32/217
# Predicting batch features
# Processing batch 33/217
# Predicting batch features
# Processing batch 34/217
# Predicting batch features
# Processing batch 35/217
# Predicting batch features
# Processing batch 36/217
# Predicting batch features
# Processing batch 37/217
# Predicting batch features
# Processing batch 38/217
# Predicting batch features
# Processing batch 39/217
# Predicting batch features
# Processing batch 40/217
# Predicting batch features
# Processing batch 41/217
# Predicting batch features
# Processing batch 42/217
# Predicting batch features
# Processing batch 43/217
# Predicting batch features
# Processing batch 44/217
# Predicting batch features
# Processing batch 45/217
# Predicting batch features
# Processing batch 46/217
# Predicting batch features
# Processing batch 47/217
# Predicting batch features
# Processing batch 48/217
# Predicting batch features
# Processing batch 49/217
# Predicting batch features
# Processing batch 50/217
# Predicting batch features
# Processing batch 51/217
# Predicting batch features
# Processing batch 52/217
# Predicting batch features
# Processing batch 53/217
# Predicting batch features
# Processing batch 54/217
# Predicting batch features
# Processing batch 55/217
# Predicting batch features
# Processing batch 56/217
# Predicting batch features
# Processing batch 57/217
# Predicting batch features
# Processing batch 58/217
# Predicting batch features
# Processing batch 59/217
# Predicting batch features
# Processing batch 60/217
# Predicting batch features
# Processing batch 61/217
# Predicting batch features
# Processing batch 62/217
# Predicting batch features
# Processing batch 63/217
# Predicting batch features
# Processing batch 64/217
# Predicting batch features
# Processing batch 65/217
# Predicting batch features
# Processing batch 66/217
# Predicting batch features
# Processing batch 67/217
# Predicting batch features
# Processing batch 68/217
# Predicting batch features
# Processing batch 69/217
# Predicting batch features
# Processing batch 70/217
# Predicting batch features
# Processing batch 71/217
# Predicting batch features
# Processing batch 72/217
# Predicting batch features
# Processing batch 73/217
# Predicting batch features
# Processing batch 74/217
# Predicting batch features
# Processing batch 75/217
# Predicting batch features
# Processing batch 76/217
# Predicting batch features
# Processing batch 77/217
# Predicting batch features
# Processing batch 78/217
# Predicting batch features
# Processing batch 79/217
# Predicting batch features
# Processing batch 80/217
# Predicting batch features
# Processing batch 81/217
# Predicting batch features
# Processing batch 82/217
# Predicting batch features
# Processing batch 83/217
# Predicting batch features
# Processing batch 84/217
# Predicting batch features
# Processing batch 85/217
# Predicting batch features
# Processing batch 86/217
# Predicting batch features
# Processing batch 87/217
# Predicting batch features
# Processing batch 88/217
# Predicting batch features
# Processing batch 89/217
# Predicting batch features
# Processing batch 90/217
# Predicting batch features
# Processing batch 91/217
# Predicting batch features
# Processing batch 92/217
# Predicting batch features
# Processing batch 93/217
# Predicting batch features
# Processing batch 94/217
# Predicting batch features
# Processing batch 95/217
# Predicting batch features
# Processing batch 96/217
# Predicting batch features
# Processing batch 97/217
# Predicting batch features
# Processing batch 98/217
# Predicting batch features
# Processing batch 99/217
# Predicting batch features
# Processing batch 100/217
# Predicting batch features
# Processing batch 101/217
# Predicting batch features
# Processing batch 102/217
# Predicting batch features
# Processing batch 103/217
# Predicting batch features
# Processing batch 104/217
# Predicting batch features
# Processing batch 105/217
# Predicting batch features
# Processing batch 106/217
# Predicting batch features
# Processing batch 107/217
# Predicting batch features
# Processing batch 108/217
# Predicting batch features
# Processing batch 109/217
# Predicting batch features
# Processing batch 110/217
# Predicting batch features
# Processing batch 111/217
# Predicting batch features
# Processing batch 112/217
# Predicting batch features
# Processing batch 113/217
# Predicting batch features
# Processing batch 114/217
# Predicting batch features
# Processing batch 115/217
# Predicting batch features
# Processing batch 116/217
# Predicting batch features
# Processing batch 117/217
# Predicting batch features
# Processing batch 118/217
# Predicting batch features
# Processing batch 119/217
# Predicting batch features
# Processing batch 120/217
# Predicting batch features
# Processing batch 121/217
# Predicting batch features
# Processing batch 122/217
# Predicting batch features
# Processing batch 123/217
# Predicting batch features
# Processing batch 124/217
# Predicting batch features
# Processing batch 125/217
# Predicting batch features
# Processing batch 126/217
# Predicting batch features
# Processing batch 127/217
# Predicting batch features
# Processing batch 128/217
# Predicting batch features
# Processing batch 129/217
# Predicting batch features
# Processing batch 130/217
# Predicting batch features
# Processing batch 131/217
# Predicting batch features
# Processing batch 132/217
# Predicting batch features
# Processing batch 133/217
# Predicting batch features
# Processing batch 134/217
# Predicting batch features
# Processing batch 135/217
# Predicting batch features
# Processing batch 136/217
# Predicting batch features
# Processing batch 137/217
# Predicting batch features
# Processing batch 138/217
# Predicting batch features
# Processing batch 139/217
# Predicting batch features
# Processing batch 140/217
# Predicting batch features
# Processing batch 141/217
# Predicting batch features
# Processing batch 142/217
# Predicting batch features
# Processing batch 143/217
# Predicting batch features
# Processing batch 144/217
# Predicting batch features
# Processing batch 145/217
# Predicting batch features
# Processing batch 146/217
# Predicting batch features
# Processing batch 147/217
# Predicting batch features
# Processing batch 148/217
# Predicting batch features
# Processing batch 149/217
# Predicting batch features
# Processing batch 150/217
# Predicting batch features
# Processing batch 151/217
# Predicting batch features
# Processing batch 152/217
# Predicting batch features
# Processing batch 153/217
# Predicting batch features
# Processing batch 154/217
# Predicting batch features
# Processing batch 155/217
# Predicting batch features
# Processing batch 156/217
# Predicting batch features
# Processing batch 157/217
# Predicting batch features
# Processing batch 158/217
# Predicting batch features
# Processing batch 159/217
# Predicting batch features
# Processing batch 160/217
# Predicting batch features
# Processing batch 161/217
# Predicting batch features
# Processing batch 162/217
# Predicting batch features
# Processing batch 163/217
# Predicting batch features
# Processing batch 164/217
# Predicting batch features
# Processing batch 165/217
# Predicting batch features
# Processing batch 166/217
# Predicting batch features
# Processing batch 167/217
# Predicting batch features
# Processing batch 168/217
# Predicting batch features
# Processing batch 169/217
# Predicting batch features
# Processing batch 170/217
# Predicting batch features
# Processing batch 171/217
# Predicting batch features
# Processing batch 172/217
# Predicting batch features
# Processing batch 173/217
# Predicting batch features
# Processing batch 174/217
# Predicting batch features
# Processing batch 175/217
# Predicting batch features
# Processing batch 176/217
# Predicting batch features
# Processing batch 177/217
# Predicting batch features
# Processing batch 178/217
# Predicting batch features
# Processing batch 179/217
# Predicting batch features
# Processing batch 180/217
# Predicting batch features
# Processing batch 181/217
# Predicting batch features
# Processing batch 182/217
# Predicting batch features
# Processing batch 183/217
# Predicting batch features
# Processing batch 184/217
# Predicting batch features
# Processing batch 185/217
# Predicting batch features
# Processing batch 186/217
# Predicting batch features
# Processing batch 187/217
# Predicting batch features
# Processing batch 188/217
# Predicting batch features
# Processing batch 189/217
# Predicting batch features
# Processing batch 190/217
# Predicting batch features
# Processing batch 191/217
# Predicting batch features
# Processing batch 192/217
# Predicting batch features
# Processing batch 193/217
# Predicting batch features
# Processing batch 194/217
# Predicting batch features
# Processing batch 195/217
# Predicting batch features
# Processing batch 196/217
# Predicting batch features
# Processing batch 197/217
# Predicting batch features
# Processing batch 198/217
# Predicting batch features
# Processing batch 199/217
# Predicting batch features
# Processing batch 200/217
# Predicting batch features
# Processing batch 201/217
# Predicting batch features
# Processing batch 202/217
# Predicting batch features
# Processing batch 203/217
# Predicting batch features
# Processing batch 204/217
# Predicting batch features
# Processing batch 205/217
# Predicting batch features
# Processing batch 206/217
# Predicting batch features
# Processing batch 207/217
# Predicting batch features
# Processing batch 208/217
# Predicting batch features
# Processing batch 209/217
# Predicting batch features
# Processing batch 210/217
# Predicting batch features
# Processing batch 211/217
# Predicting batch features
# Processing batch 212/217
# Predicting batch features
# Processing batch 213/217
# Predicting batch features
# Processing batch 214/217
# Predicting batch features
# Processing batch 215/217
# Predicting batch features
# Processing batch 216/217
# Predicting batch features
# Processing batch 217/217
# Predicting batch features
# ('Iteration: ', 1)
# Processing batch 1/617
# ('Training batch: ', 1)
# Processing batch 2/617
# ('Training batch: ', 2)
# Processing batch 3/617
# ('Training batch: ', 3)
# Processing batch 4/617
# ('Training batch: ', 4)
# Processing batch 5/617
# ('Training batch: ', 5)
# Processing batch 6/617
# ('Training batch: ', 6)
# Processing batch 7/617
# ('Training batch: ', 7)
# Processing batch 8/617
# ('Training batch: ', 8)
# Processing batch 9/617
# ('Training batch: ', 9)
# Processing batch 10/617
# ('Training batch: ', 10)
# Processing batch 11/617
# ('Training batch: ', 11)
# Processing batch 12/617
# ('Training batch: ', 12)
# Processing batch 13/617
# ('Training batch: ', 13)
# Processing batch 14/617
# ('Training batch: ', 14)
# Processing batch 15/617
# ('Training batch: ', 15)
# Processing batch 16/617
# ('Training batch: ', 16)
# Processing batch 17/617
# ('Training batch: ', 17)
# Processing batch 18/617
# ('Training batch: ', 18)
# Processing batch 19/617
# ('Training batch: ', 19)
# Processing batch 20/617
# ('Training batch: ', 20)
# Processing batch 21/617
# ('Training batch: ', 21)
# Processing batch 22/617
# ('Training batch: ', 22)
# Processing batch 23/617
# ('Training batch: ', 23)
# Processing batch 24/617
# ('Training batch: ', 24)
# Processing batch 25/617
# ('Training batch: ', 25)
# Processing batch 26/617
# ('Training batch: ', 26)
# Processing batch 27/617
# ('Training batch: ', 27)
# Processing batch 28/617
# ('Training batch: ', 28)
# Processing batch 29/617
# ('Training batch: ', 29)
# Processing batch 30/617
# ('Training batch: ', 30)
# Processing batch 31/617
# ('Training batch: ', 31)
# Processing batch 32/617
# ('Training batch: ', 32)
# Processing batch 33/617
# ('Training batch: ', 33)
# Processing batch 34/617
# ('Training batch: ', 34)
# Processing batch 35/617
# ('Training batch: ', 35)
# Processing batch 36/617
# ('Training batch: ', 36)
# Processing batch 37/617
# ('Training batch: ', 37)
# Processing batch 38/617
# ('Training batch: ', 38)
# Processing batch 39/617
# ('Training batch: ', 39)
# Processing batch 40/617
# ('Training batch: ', 40)
# Processing batch 41/617
# ('Training batch: ', 41)
# Processing batch 42/617
# ('Training batch: ', 42)
# Processing batch 43/617
# ('Training batch: ', 43)
# Processing batch 44/617
# ('Training batch: ', 44)
# Processing batch 45/617
# ('Training batch: ', 45)
# Processing batch 46/617
# ('Training batch: ', 46)
# Processing batch 47/617
# ('Training batch: ', 47)
# Processing batch 48/617
# ('Training batch: ', 48)
# Processing batch 49/617
# ('Training batch: ', 49)
# Processing batch 50/617
# ('Training batch: ', 50)
# Processing batch 51/617
# ('Training batch: ', 51)
# Processing batch 52/617
# ('Training batch: ', 52)
# Processing batch 53/617
# ('Training batch: ', 53)
# Processing batch 54/617
# ('Training batch: ', 54)
# Processing batch 55/617
# ('Training batch: ', 55)
# Processing batch 56/617
# ('Training batch: ', 56)
# Processing batch 57/617
# ('Training batch: ', 57)
# Processing batch 58/617
# ('Training batch: ', 58)
# Processing batch 59/617
# ('Training batch: ', 59)
# Processing batch 60/617
# ('Training batch: ', 60)
# Processing batch 61/617
# ('Training batch: ', 61)
# Processing batch 62/617
# ('Training batch: ', 62)
# Processing batch 63/617
# ('Training batch: ', 63)
# Processing batch 64/617
# ('Training batch: ', 64)
# Processing batch 65/617
# ('Training batch: ', 65)
# Processing batch 66/617
# ('Training batch: ', 66)
# Processing batch 67/617
# ('Training batch: ', 67)
# Processing batch 68/617
# ('Training batch: ', 68)
# Processing batch 69/617
# ('Training batch: ', 69)
# Processing batch 70/617
# ('Training batch: ', 70)
# Processing batch 71/617
# ('Training batch: ', 71)
# Processing batch 72/617
# ('Training batch: ', 72)
# Processing batch 73/617
# ('Training batch: ', 73)
# Processing batch 74/617
# ('Training batch: ', 74)
# Processing batch 75/617
# ('Training batch: ', 75)
# Processing batch 76/617
# ('Training batch: ', 76)
# Processing batch 77/617
# ('Training batch: ', 77)
# Processing batch 78/617
# ('Training batch: ', 78)
# Processing batch 79/617
# ('Training batch: ', 79)
# Processing batch 80/617
# ('Training batch: ', 80)
# Processing batch 81/617
# ('Training batch: ', 81)
# Processing batch 82/617
# ('Training batch: ', 82)
# Processing batch 83/617
# ('Training batch: ', 83)
# Processing batch 84/617
# ('Training batch: ', 84)
# Processing batch 85/617
# ('Training batch: ', 85)
# Processing batch 86/617
# ('Training batch: ', 86)
# Processing batch 87/617
# ('Training batch: ', 87)
# Processing batch 88/617
# ('Training batch: ', 88)
# Processing batch 89/617
# ('Training batch: ', 89)
# Processing batch 90/617
# ('Training batch: ', 90)
# Processing batch 91/617
# ('Training batch: ', 91)
# Processing batch 92/617
# ('Training batch: ', 92)
# Processing batch 93/617
# ('Training batch: ', 93)
# Processing batch 94/617
# ('Training batch: ', 94)
# Processing batch 95/617
# ('Training batch: ', 95)
# Processing batch 96/617
# ('Training batch: ', 96)
# Processing batch 97/617
# ('Training batch: ', 97)
# Processing batch 98/617
# ('Training batch: ', 98)
# Processing batch 99/617
# ('Training batch: ', 99)
# Processing batch 100/617
# ('Training batch: ', 100)
# Processing batch 101/617
# ('Training batch: ', 101)
# Processing batch 102/617
# ('Training batch: ', 102)
# Processing batch 103/617
# ('Training batch: ', 103)
# Processing batch 104/617
# ('Training batch: ', 104)
# Processing batch 105/617
# ('Training batch: ', 105)
# Processing batch 106/617
# ('Training batch: ', 106)
# Processing batch 107/617
# ('Training batch: ', 107)
# Processing batch 108/617
# ('Training batch: ', 108)
# Processing batch 109/617
# ('Training batch: ', 109)
# Processing batch 110/617
# ('Training batch: ', 110)
# Processing batch 111/617
# ('Training batch: ', 111)
# Processing batch 112/617
# ('Training batch: ', 112)
# Processing batch 113/617
# ('Training batch: ', 113)
# Processing batch 114/617
# ('Training batch: ', 114)
# Processing batch 115/617
# ('Training batch: ', 115)
# Processing batch 116/617
# ('Training batch: ', 116)
# Processing batch 117/617
# ('Training batch: ', 117)
# Processing batch 118/617
# ('Training batch: ', 118)
# Processing batch 119/617
# ('Training batch: ', 119)
# Processing batch 120/617
# ('Training batch: ', 120)
# Processing batch 121/617
# ('Training batch: ', 121)
# Processing batch 122/617
# ('Training batch: ', 122)
# Processing batch 123/617
# ('Training batch: ', 123)
# Processing batch 124/617
# ('Training batch: ', 124)
# Processing batch 125/617
# ('Training batch: ', 125)
# Processing batch 126/617
# ('Training batch: ', 126)
# Processing batch 127/617
# ('Training batch: ', 127)
# Processing batch 128/617
# ('Training batch: ', 128)
# Processing batch 129/617
# ('Training batch: ', 129)
# Processing batch 130/617
# ('Training batch: ', 130)
# Processing batch 131/617
# ('Training batch: ', 131)
# Processing batch 132/617
# ('Training batch: ', 132)
# Processing batch 133/617
# ('Training batch: ', 133)
# Processing batch 134/617
# ('Training batch: ', 134)
# Processing batch 135/617
# ('Training batch: ', 135)
# Processing batch 136/617
# ('Training batch: ', 136)
# Processing batch 137/617
# ('Training batch: ', 137)
# Processing batch 138/617
# ...
# ('Training batch: ', 693)
# Processing batch 694/791
# ('Training batch: ', 694)
# Processing batch 695/791
# ('Training batch: ', 695)
# Processing batch 696/791
# ('Training batch: ', 696)
# Processing batch 697/791
# ('Training batch: ', 697)
# Processing batch 698/791
# ('Training batch: ', 698)
# Processing batch 699/791
# ('Training batch: ', 699)
# Processing batch 700/791
# ('Training batch: ', 700)
# Processing batch 701/791
# ('Training batch: ', 701)
# Processing batch 702/791
# ('Training batch: ', 702)
# Processing batch 703/791
# ('Training batch: ', 703)
# Processing batch 704/791
# ('Training batch: ', 704)
# Processing batch 705/791
# ('Training batch: ', 705)
# Processing batch 706/791
# ('Training batch: ', 706)
# Processing batch 707/791
# ('Training batch: ', 707)
# Processing batch 708/791
# ('Training batch: ', 708)
# Processing batch 709/791
# ('Training batch: ', 709)
# Processing batch 710/791
# ('Training batch: ', 710)
# Processing batch 711/791
# ('Training batch: ', 711)
# Processing batch 712/791
# ('Training batch: ', 712)
# Processing batch 713/791
# ('Training batch: ', 713)
# Processing batch 714/791
# ('Training batch: ', 714)
# Processing batch 715/791
# ('Training batch: ', 715)
# Processing batch 716/791
# ('Training batch: ', 716)
# Processing batch 717/791
# ('Training batch: ', 717)
# Processing batch 718/791
# ('Training batch: ', 718)
# Processing batch 719/791
# ('Training batch: ', 719)
# Processing batch 720/791
# ('Training batch: ', 720)
# Processing batch 721/791
# ('Training batch: ', 721)
# Processing batch 722/791
# ('Training batch: ', 722)
# Processing batch 723/791
# ('Training batch: ', 723)
# Processing batch 724/791
# ('Training batch: ', 724)
# Processing batch 725/791
# ('Training batch: ', 725)
# Processing batch 726/791
# ('Training batch: ', 726)
# Processing batch 727/791
# ('Training batch: ', 727)
# Processing batch 728/791
# ('Training batch: ', 728)
# Processing batch 729/791
# ('Training batch: ', 729)
# Processing batch 730/791
# ('Training batch: ', 730)
# Processing batch 731/791
# ('Training batch: ', 731)
# Processing batch 732/791
# ('Training batch: ', 732)
# Processing batch 733/791
# ('Training batch: ', 733)
# Processing batch 734/791
# ('Training batch: ', 734)
# Processing batch 735/791
# ('Training batch: ', 735)
# Processing batch 736/791
# ('Training batch: ', 736)
# Processing batch 737/791
# ('Training batch: ', 737)
# Processing batch 738/791
# ('Training batch: ', 738)
# Processing batch 739/791
# ('Training batch: ', 739)
# Processing batch 740/791
# ('Training batch: ', 740)
# Processing batch 741/791
# ('Training batch: ', 741)
# Processing batch 742/791
# ('Training batch: ', 742)
# Processing batch 743/791
# ('Training batch: ', 743)
# Processing batch 744/791
# ('Training batch: ', 744)
# Processing batch 745/791
# ('Training batch: ', 745)
# Processing batch 746/791
# ('Training batch: ', 746)
# Processing batch 747/791
# ('Training batch: ', 747)
# Processing batch 748/791
# ('Training batch: ', 748)
# Processing batch 749/791
# ('Training batch: ', 749)
# Processing batch 750/791
# ('Training batch: ', 750)
# Processing batch 751/791
# ('Training batch: ', 751)
# Processing batch 752/791
# ('Training batch: ', 752)
# Processing batch 753/791
# ('Training batch: ', 753)
# Processing batch 754/791
# ('Training batch: ', 754)
# Processing batch 755/791
# ('Training batch: ', 755)
# Processing batch 756/791
# ('Training batch: ', 756)
# Processing batch 757/791
# ('Training batch: ', 757)
# Processing batch 758/791
# ('Training batch: ', 758)
# Processing batch 759/791
# ('Training batch: ', 759)
# Processing batch 760/791
# ('Training batch: ', 760)
# Processing batch 761/791
# ('Training batch: ', 761)
# Processing batch 762/791
# ('Training batch: ', 762)
# Processing batch 763/791
# ('Training batch: ', 763)
# Processing batch 764/791
# ('Training batch: ', 764)
# Processing batch 765/791
# ('Training batch: ', 765)
# Processing batch 766/791
# ('Training batch: ', 766)
# Processing batch 767/791
# ('Training batch: ', 767)
# Processing batch 768/791
# ('Training batch: ', 768)
# Processing batch 769/791
# ('Training batch: ', 769)
# Processing batch 770/791
# ('Training batch: ', 770)
# Processing batch 771/791
# ('Training batch: ', 771)
# Processing batch 772/791
# ('Training batch: ', 772)
# Processing batch 773/791
# ('Training batch: ', 773)
# Processing batch 774/791
# ('Training batch: ', 774)
# Processing batch 775/791
# ('Training batch: ', 775)
# Processing batch 776/791
# ('Training batch: ', 776)
# Processing batch 777/791
# ('Training batch: ', 777)
# Processing batch 778/791
# ('Training batch: ', 778)
# Processing batch 779/791
# ('Training batch: ', 779)
# Processing batch 780/791
# ('Training batch: ', 780)
# Processing batch 781/791
# ('Training batch: ', 781)
# Processing batch 782/791
# ('Training batch: ', 782)
# Processing batch 783/791
# ('Training batch: ', 783)
# Processing batch 784/791
# ('Training batch: ', 784)
# Processing batch 785/791
# ('Training batch: ', 785)
# Processing batch 786/791
# ('Training batch: ', 786)
# Processing batch 787/791
# ('Training batch: ', 787)
# Processing batch 788/791
# ('Training batch: ', 788)
# Processing batch 789/791
# ('Training batch: ', 789)
# Processing batch 790/791
# ('Training batch: ', 790)
# Processing batch 791/791
# ('Training batch: ', 791)
# Processing batch 1/217
# Predicting batch features
# Processing batch 2/217
# Predicting batch features
# Processing batch 3/217
# Predicting batch features
# Processing batch 4/217
# Predicting batch features
# Processing batch 5/217
# Predicting batch features
# Processing batch 6/217
# Predicting batch features
# Processing batch 7/217
# Predicting batch features
# Processing batch 8/217
# Predicting batch features
# Processing batch 9/217
# Predicting batch features
# Processing batch 10/217
# Predicting batch features
# Processing batch 11/217
# Predicting batch features
# Processing batch 12/217
# Predicting batch features
# Processing batch 13/217
# Predicting batch features
# Processing batch 14/217
# Predicting batch features
# Processing batch 15/217
# Predicting batch features
# Processing batch 16/217
# Predicting batch features
# Processing batch 17/217
# Predicting batch features
# Processing batch 18/217
# Predicting batch features
# Processing batch 19/217
# Predicting batch features
# Processing batch 20/217
# Predicting batch features
# Processing batch 21/217
# Predicting batch features
# Processing batch 22/217
# Predicting batch features
# Processing batch 23/217
# Predicting batch features
# Processing batch 24/217
# Predicting batch features
# Processing batch 25/217
# Predicting batch features
# Processing batch 26/217
# Predicting batch features
# Processing batch 27/217
# Predicting batch features
# Processing batch 28/217
# Predicting batch features
# Processing batch 29/217
# Predicting batch features
# Processing batch 30/217
# Predicting batch features
# Processing batch 31/217
# Predicting batch features
# Processing batch 32/217
# Predicting batch features
# Processing batch 33/217
# Predicting batch features
# Processing batch 34/217
# Predicting batch features
# Processing batch 35/217
# Predicting batch features
# Processing batch 36/217
# Predicting batch features
# Processing batch 37/217
# Predicting batch features
# Processing batch 38/217
# Predicting batch features
# Processing batch 39/217
# Predicting batch features
# Processing batch 40/217
# Predicting batch features
# Processing batch 41/217
# Predicting batch features
# Processing batch 42/217
# Predicting batch features
# Processing batch 43/217
# Predicting batch features
# Processing batch 44/217
# Predicting batch features
# Processing batch 45/217
# Predicting batch features
# Processing batch 46/217
# Predicting batch features
# Processing batch 47/217
# Predicting batch features
# Processing batch 48/217
# Predicting batch features
# Processing batch 49/217
# Predicting batch features
# Processing batch 50/217
# Predicting batch features
# Processing batch 51/217
# Predicting batch features
# Processing batch 52/217
# Predicting batch features
# Processing batch 53/217
# Predicting batch features
# Processing batch 54/217
# Predicting batch features
# Processing batch 55/217
# Predicting batch features
# Processing batch 56/217
# Predicting batch features
# Processing batch 57/217
# Predicting batch features
# Processing batch 58/217
# Predicting batch features
# Processing batch 59/217
# Predicting batch features
# Processing batch 60/217
# Predicting batch features
# Processing batch 61/217
# Predicting batch features
# Processing batch 62/217
# Predicting batch features
# Processing batch 63/217
# Predicting batch features
# Processing batch 64/217
# Predicting batch features
# Processing batch 65/217
# Predicting batch features
# Processing batch 66/217
# Predicting batch features
# Processing batch 67/217
# Predicting batch features
# Processing batch 68/217
# Predicting batch features
# Processing batch 69/217
# Predicting batch features
# Processing batch 70/217
# Predicting batch features
# Processing batch 71/217
# Predicting batch features
# Processing batch 72/217
# Predicting batch features
# Processing batch 73/217
# Predicting batch features
# Processing batch 74/217
# Predicting batch features
# Processing batch 75/217
# Predicting batch features
# Processing batch 76/217
# Predicting batch features
# Processing batch 77/217
# Predicting batch features
# Processing batch 78/217
# Predicting batch features
# Processing batch 79/217
# Predicting batch features
# Processing batch 80/217
# Predicting batch features
# Processing batch 81/217
# Predicting batch features
# Processing batch 82/217
# Predicting batch features
# Processing batch 83/217
# Predicting batch features
# Processing batch 84/217
# Predicting batch features
# Processing batch 85/217
# Predicting batch features
# Processing batch 86/217
# Predicting batch features
# Processing batch 87/217
# Predicting batch features
# Processing batch 88/217
# Predicting batch features
# Processing batch 89/217
# Predicting batch features
# Processing batch 90/217
# Predicting batch features
# Processing batch 91/217
# Predicting batch features
# Processing batch 92/217
# Predicting batch features
# Processing batch 93/217
# Predicting batch features
# Processing batch 94/217
# Predicting batch features
# Processing batch 95/217
# Predicting batch features
# Processing batch 96/217
# Predicting batch features
# Processing batch 97/217
# Predicting batch features
# Processing batch 98/217
# Predicting batch features
# Processing batch 99/217
# Predicting batch features
# Processing batch 100/217
# Predicting batch features
# Processing batch 101/217
# Predicting batch features
# Processing batch 102/217
# Predicting batch features
# Processing batch 103/217
# Predicting batch features
# Processing batch 104/217
# Predicting batch features
# Processing batch 105/217
# Predicting batch features
# Processing batch 106/217
# Predicting batch features
# Processing batch 107/217
# Predicting batch features
# Processing batch 108/217
# Predicting batch features
# Processing batch 109/217
# Predicting batch features
# Processing batch 110/217
# Predicting batch features
# Processing batch 111/217
# Predicting batch features
# Processing batch 112/217
# Predicting batch features
# Processing batch 113/217
# Predicting batch features
# Processing batch 114/217
# Predicting batch features
# Processing batch 115/217
# Predicting batch features
# Processing batch 116/217
# Predicting batch features
# Processing batch 117/217
# Predicting batch features
# Processing batch 118/217
# Predicting batch features
# Processing batch 119/217
# Predicting batch features
# Processing batch 120/217
# Predicting batch features
# Processing batch 121/217
# Predicting batch features
# Processing batch 122/217
# Predicting batch features
# Processing batch 123/217
# Predicting batch features
# Processing batch 124/217
# Predicting batch features
# Processing batch 125/217
# Predicting batch features
# Processing batch 126/217
# Predicting batch features
# Processing batch 127/217
# Predicting batch features
# Processing batch 128/217
# Predicting batch features
# Processing batch 129/217
# Predicting batch features
# Processing batch 130/217
# Predicting batch features
# Processing batch 131/217
# Predicting batch features
# Processing batch 132/217
# Predicting batch features
# Processing batch 133/217
# Predicting batch features
# Processing batch 134/217
# Predicting batch features
# Processing batch 135/217
# Predicting batch features
# Processing batch 136/217
# Predicting batch features
# Processing batch 137/217
# Predicting batch features
# Processing batch 138/217
# Predicting batch features
# Processing batch 139/217
# Predicting batch features
# Processing batch 140/217
# Predicting batch features
# Processing batch 141/217
# Predicting batch features
# Processing batch 142/217
# Predicting batch features
# Processing batch 143/217
# Predicting batch features
# Processing batch 144/217
# Predicting batch features
# Processing batch 145/217
# Predicting batch features
# Processing batch 146/217
# Predicting batch features
# Processing batch 147/217
# Predicting batch features
# Processing batch 148/217
# Predicting batch features
# Processing batch 149/217
# Predicting batch features
# Processing batch 150/217
# Predicting batch features
# Processing batch 151/217
# Predicting batch features
# Processing batch 152/217
# Predicting batch features
# Processing batch 153/217
# Predicting batch features
# Processing batch 154/217
# Predicting batch features
# Processing batch 155/217
# Predicting batch features
# Processing batch 156/217
# Predicting batch features
# Processing batch 157/217
# Predicting batch features
# Processing batch 158/217
# Predicting batch features
# Processing batch 159/217
# Predicting batch features
# Processing batch 160/217
# Predicting batch features
# Processing batch 161/217
# Predicting batch features
# Processing batch 162/217
# Predicting batch features
# Processing batch 163/217
# Predicting batch features
# Processing batch 164/217
# Predicting batch features
# Processing batch 165/217
# Predicting batch features
# Processing batch 166/217
# Predicting batch features
# Processing batch 167/217
# Predicting batch features
# Processing batch 168/217
# Predicting batch features
# Processing batch 169/217
# Predicting batch features
# Processing batch 170/217
# Predicting batch features
# Processing batch 171/217
# Predicting batch features
# Processing batch 172/217
# Predicting batch features
# Processing batch 173/217
# Predicting batch features
# Processing batch 174/217
# Predicting batch features
# Processing batch 175/217
# Predicting batch features
# Processing batch 176/217
# Predicting batch features
# Processing batch 177/217
# Predicting batch features
# Processing batch 178/217
# Predicting batch features
# Processing batch 179/217
# Predicting batch features
# Processing batch 180/217
# Predicting batch features
# Processing batch 181/217
# Predicting batch features
# Processing batch 182/217
# Predicting batch features
# Processing batch 183/217
# Predicting batch features
# Processing batch 184/217
# Predicting batch features
# Processing batch 185/217
# Predicting batch features
# Processing batch 186/217
# Predicting batch features
# Processing batch 187/217
# Predicting batch features
# Processing batch 188/217
# Predicting batch features
# Processing batch 189/217
# Predicting batch features
# Processing batch 190/217
# Predicting batch features
# Processing batch 191/217
# Predicting batch features
# Processing batch 192/217
# Predicting batch features
# Processing batch 193/217
# Predicting batch features
# Processing batch 194/217
# Predicting batch features
# Processing batch 195/217
# Predicting batch features
# Processing batch 196/217
# Predicting batch features
# Processing batch 197/217
# Predicting batch features
# Processing batch 198/217
# Predicting batch features
# Processing batch 199/217
# Predicting batch features
# Processing batch 200/217
# Predicting batch features
# Processing batch 201/217
# Predicting batch features
# Processing batch 202/217
# Predicting batch features
# Processing batch 203/217
# Predicting batch features
# Processing batch 204/217
# Predicting batch features
# Processing batch 205/217
# Predicting batch features
# Processing batch 206/217
# Predicting batch features
# Processing batch 207/217
# Predicting batch features
# Processing batch 208/217
# Predicting batch features
# Processing batch 209/217
# Predicting batch features
# Processing batch 210/217
# Predicting batch features
# Processing batch 211/217
# Predicting batch features
# Processing batch 212/217
# Predicting batch features
# Processing batch 213/217
# Predicting batch features
# Processing batch 214/217
# Predicting batch features
# Processing batch 215/217
# Predicting batch features
# Processing batch 216/217
# Predicting batch features
# Processing batch 217/217
# Predicting batch features

# %%
for i in mean_acc:
    plt.figure()
    plt.plot(i)
    plt.title('Accuracy over iterations (for model %s)' % i)
    plt.xlabel('# Iterations')
    plt.ylabel('SVM mean accuracy')
    plt.show()

# %%
classes = ['aeroplane', 'bicycle', 'bus', 'car', 'horse', 'knife', 'motorcycle', 'person', 'plant', 'skateboard', 
           'train', 'truck']

# %%
for i in pred:
    print(classification_report(labels_t, i, target_names = classes))
# Out:
#               precision    recall  f1-score   support
#
#    aeroplane       0.10      0.17      0.12      3646
#      bicycle       0.05      0.04      0.04      3475
#          bus       0.09      0.23      0.13      4690
#          car       0.20      0.50      0.28     10401
#        horse       0.10      0.00      0.01      4691
#        knife       0.08      0.00      0.00      2075
#   motorcycle       0.17      0.06      0.09      5796
#       person       0.06      0.00      0.00      4000
#        plant       0.17      0.05      0.08      4549
#   skateboard       0.04      0.04      0.04      2281
#        train       0.03      0.01      0.02      4236
#        truck       0.08      0.01      0.01      5548
#
#    micro avg       0.14      0.14      0.14     55388
#    macro avg       0.10      0.09      0.07     55388
# weighted avg       0.11      0.14      0.10     55388
#
#               precision    recall  f1-score   support
#
#    aeroplane       0.11      0.00      0.01      3646
#      bicycle       0.05      0.01      0.02      3475
#          bus       0.08      0.56      0.15      4690
#          car       0.21      0.20      0.20     10401
#        horse       0.25      0.00      0.00      4691
#        knife       0.07      0.00      0.00      2075
#   motorcycle       0.17      0.04      0.06      5796
#       person       0.06      0.00      0.01      4000
#        plant       0.12      0.02      0.03      4549
#   skateboard       0.03      0.00      0.01      2281
#        train       0.07      0.18      0.10      4236
#        truck       0.10      0.01      0.01      5548
#
#    micro avg       0.11      0.11      0.11     55388
#    macro avg       0.11      0.09      0.05     55388
# weighted avg       0.13      0.11      0.07     55388
#
#               precision    recall  f1-score   support
#
#    aeroplane       0.11      0.02      0.03      3646
#      bicycle       0.06      0.04      0.05      3475
#          bus       0.07      0.23      0.11      4690
#          car       0.21      0.26      0.24     10401
#        horse       0.08      0.01      0.02      4691
#        knife       0.17      0.01      0.01      2075
#   motorcycle       0.14      0.14      0.14      5796
#       person       0.06      0.01      0.01      4000
#        plant       0.09      0.10      0.10      4549
#   skateboard       0.03      0.01      0.01      2281
#        train       0.08      0.20      0.11      4236
#        truck       0.08      0.01      0.02      5548
#
#    micro avg       0.11      0.11      0.11     55388
#    macro avg       0.10      0.09      0.07     55388
# weighted avg       0.11      0.11      0.10     55388

# %%
majority_vote = np.maximum.reduce([pred[0], pred[1], pred[2]])

# %%
print(classification_report(labels_t, majority_vote, target_names = classes))
# Out:
#               precision    recall  f1-score   support
#
#    aeroplane       0.12      0.00      0.00      3646
#      bicycle       0.06      0.01      0.02      3475
#          bus       0.07      0.18      0.10      4690
#          car       0.21      0.33      0.25     10401
#        horse       0.06      0.01      0.01      4691
#        knife       0.10      0.00      0.01      2075
#   motorcycle       0.12      0.09      0.11      5796
#       person       0.06      0.01      0.01      4000
#        plant       0.10      0.09      0.09      4549
#   skateboard       0.04      0.04      0.04      2281
#        train       0.08      0.26      0.12      4236
#        truck       0.09      0.02      0.03      5548
#
#    micro avg       0.12      0.12      0.12     55388
#    macro avg       0.09      0.09      0.07     55388
# weighted avg       0.11      0.12      0.09     55388
